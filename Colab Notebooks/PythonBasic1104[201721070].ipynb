# %%
print('주석은 #으로!') #주석입니다
#주석은 프로그램 시 실행이 안됨
# Out:
# 주석은 #으로!

# %%
5.777e+3 #*10^3을 의미함 / 정수랑 플로트 있음. +생략 가능
# Out:
# 5777.0

# %%
"따움표로 표현해도 결과 값은 ''로 나온다!" # 코드안에서 슬래시\를 치면 다음줄에도 이어지는 것을 알려줌. 멀티라인. 혹은 ''' 로 감싸주면 됨
# Out:
# "따움표로 표현해도 결과 값은 ''로 나온다!"

# %%
print("슬래시로 멀티라인\
멀티입니다!")
# Out:
# 슬래시로 멀티라인멀티입니다!

# %%
#따움표 표시하고 싶으면 ' 에 "를 넣든 "에 '을 넣든!

# %%
"""
한줄
두줄
세줄
"""
# Out:
# '\n한줄\n두줄\n세줄\n'

# %%
"{} 중괄호 안에 내용을 뒤에 포맷팅으로 넣을 수 있음! 문자열에 format 함수.".format("첫번째 매개변수")#문자열 포맷팅
# Out:
# '첫번째 매개변수 중괄호 안에 내용을 뒤에 포맷팅으로 넣을 수 있음! 문자열에 format 함수.'

# %%
# 위에 포멧팅을 권장하지 않음. 오류를 범할 수 있음.

# %%
"{1} 매개변수 1번 {0} 매개변수 0번".format("매개변수 0", "매개변수 1")#문자열 포맷팅
# Out:
# '매개변수 1 매개변수 1번 매개변수 0 매개변수 0번'

# %%
"{name} keyword = name, {num} keyword = num".format(name="이름", num="08")
# Out:
# '이름 keyword = name, 08 keyword = num'

# %%
#str -> 숫자를 문자열로 바꿔주는 메소드
name = "택"
age = 23

name + " is " + str(age) + " years old"
# Out:
# '택 is 23 years old'

# %%
print("{:.3f}".format(3.141592)) # 소수점 3자리까지!
# Out:
# 3.142

# %%
print("{:_^12}".format("hyotaek")) #가운데 정렬!
# Out:
# __hyotaek___

# %%
print("{:_<12}".format("hyotaek")) #왼쪽 정렬!
# Out:
# hyotaek_____

# %%
#이스케이프 문자 '' 안에 '넣기! '\'blah' 하면 사용가능함.  \는 다음에 특별한게 올거야~ 를 뜻함. \n은 newline \t tap

# %% [markdown]
# #변수
# 값을 저장하는 그릇
#
# #식별자 이름 짓기
# 예약어는 사용해선 안돼
# + if, for, while, else etc...
# + 식별자의 첫문자는 알파멧 문자 또는 _
# + 첫문자 이후엔 숫자써도 됨
# + 대소문자 구분해야함
# + 공백은 안됨
# + -+/& 이런거 쓰면 안돼 연산자도 써선 안돼

# %%
a=3
b=5

print(int(a)+b)

print("문자"*b) # 문자열 다섯번 출력 대박 순서 바껴도 된다

#문자가 플로트도 됨 플로트 연산하면 플로트가 됨

#print(8.0*"text") 플로트는 안되네
# Out:
# 8
# 문자문자문자문자문자
# texttexttexttexttexttexttexttext

# %% [markdown]
# #들여쓰기
# 들여쓰기는 완전 중요함
#
# 명령의 범위를 구분하는데 사용
#
# 인덴테이션이 아주 중요함 탭 안맞춰주면 오류가 남.

# %%
a = 5
if a == 5: # ;가 아닌 :임.! 찾아보니까 세미콜론을 안쓰고 굳이 쓴다면 한줄에 여러코드 넣는거?
  print('right')
else:
    print('else')
# Out:
# right
